# %%
import pandas as pd

# %%
dataset_path = 'datasets/init/malicious_46k.csv'

# %%
df = pd.read_csv(dataset_path)

if 'label' not in df.columns:
    df['label'] = 1
if 'Unnamed: 0' in df.columns:
    df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                                      URL  URL_Length  \
# 0                                https://t.co/5kSQ9R4oPM          23
# 1      https://technoindiagroup.com/secure-massage871...          62
# 2                                https://com-xiiiyo.vip/          23
# 3      https://1B0TC.trk.elasticemail.com/tracking/cl...         204
# 4      https://planedu.in/Facebook/Url/swisra/cantona...          51
# ...                                                  ...         ...
# 46277  https://docs.google.com/presentation/d/e/2PACX...         200
# 46278                  https://chaniago10342.start.page/          33
# 46279  https://pub-6cdf5fa1af6b4b5987c424c8bd5575fe.r...          61
# 46280             https://ohioturnpike.org-ticketrv.xin/          38
# 46281                           http://www.justflyme.com          24
#
#        Url_Shortening  Ssl_Info  Global_Ranking  Has_Suspicious_Params  \
# ...

# %%
df.to_csv(dataset_path, index=False)
